# %% [markdown]
# # Imports

# %%
# import libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# API
import requests
import json
import os

# Date
import datetime as datetime
from sodapy import Socrata
# from datetime import timedelta

# %% [markdown]
# ## API Call: NYC Parking Tickets

# %%
# Export SODAPY_APPTOKEN=<token>

socrata_domain = 'data.cityofnewyork.us'
socrata_dataset_identifier = 'nc67-uf89'
socrata_token = os.environ.get("SODAPY_APPTOKEN")

# %%
client = Socrata(socrata_domain, socrata_token)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}")
# .format(**client.__dict__)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: {domain:}
# Session: {session:}
# URI Prefix: {uri_prefix:}

# %%
#Identirfy all columns available in dataset

metadata = client.get_metadata(socrata_dataset_identifier)
[x['name'] for x in metadata['columns']]
# Out:
# ['Plate',
#  'State',
#  'License Type',
#  'Summons Number',
#  'Issue Date',
#  'Violation Time',
#  'Violation',
#  'Judgment Entry Date',
#  'Fine Amount',
#  'Penalty Amount',
#  'Interest Amount',
#  'Reduction Amount',
#  'Payment Amount',
#  'Amount Due',
#  'Precinct',
#  'County',
#  'Issuing Agency',
#  'Violation Status',
#  'Summons Image']

# %%
#Pull API. Limit number identified previously at the

results = client.get(socrata_dataset_identifier,\
                     select=('Plate, State,Issue_Date,Violation_Time,Fine_Amount,Amount_Due,Payment_Amount,\
                     Precinct,County'),\
                     where ="(violation='NO PARKING-STREET CLEANING')",\
#                     limit=10000)
                     limit=6766400)
results_df = pd.DataFrame.from_dict(results)
results_df.head()
# Out:
#       Plate State  Issue_Date Violation_Time Fine_Amount Amount_Due  \
# 0   FPN3956    NY  03/17/2020         08:48A          65          0
# 1   JNW6335    NY  03/12/2020         09:37A          65          0
# 2   GAR6585    NY  03/17/2020         10:00A          65          0
# 3  ALXHONEY    NY  03/17/2020         12:28P          65          0
# 4   DUE2948    NY  03/14/2020         08:47A          65          0
#
#   Payment_Amount Precinct County
# 0             65      046     BX
# 1             65      077      K
# 2             65      060      K
# 3             65      067      K
# 4             65      068      K

# %%
results_df.shape
# Out:
# (6766380, 9)

# %% [markdown]
# # Data Analysis

# %%
violation_df = results_df.copy()

# %% [markdown]
# ## Data Cleaning

# %%
violation_df.head()
# Out:
#       Plate State  Issue_Date Violation_Time Fine_Amount Amount_Due  \
# 0   FPN3956    NY  03/17/2020         08:48A          65          0
# 1   JNW6335    NY  03/12/2020         09:37A          65          0
# 2   GAR6585    NY  03/17/2020         10:00A          65          0
# 3  ALXHONEY    NY  03/17/2020         12:28P          65          0
# 4   DUE2948    NY  03/14/2020         08:47A          65          0
#
#   Payment_Amount Precinct County
# 0             65      046     BX
# 1             65      077      K
# 2             65      060      K
# 3             65      067      K
# 4             65      068      K

# %%
violation_df['time_issued'] = (violation_df['Issue_Date'] + ' ' + violation_df['Violation_Time'])
violation_df.head()
# Out:
#       Plate State  Issue_Date Violation_Time Fine_Amount Amount_Due  \
# 0   FPN3956    NY  03/17/2020         08:48A          65          0
# 1   JNW6335    NY  03/12/2020         09:37A          65          0
# 2   GAR6585    NY  03/17/2020         10:00A          65          0
# 3  ALXHONEY    NY  03/17/2020         12:28P          65          0
# 4   DUE2948    NY  03/14/2020         08:47A          65          0
#
#   Payment_Amount Precinct County        time_issued
# 0             65      046     BX  03/17/2020 08:48A
# 1             65      077      K  03/12/2020 09:37A
# 2             65      060      K  03/17/2020 10:00A
# 3             65      067      K  03/17/2020 12:28P
# 4             65      068      K  03/14/2020 08:47A

# %%
violation_df['time_issued']=pd.to_datetime(violation_df['time_issued'], errors='coerce')
violation_df.head(10)
# Out:
#       Plate State  Issue_Date Violation_Time Fine_Amount Amount_Due  \
# 0   FPN3956    NY  03/17/2020         08:48A          65          0
# 1   JNW6335    NY  03/12/2020         09:37A          65          0
# 2   GAR6585    NY  03/17/2020         10:00A          65          0
# 3  ALXHONEY    NY  03/17/2020         12:28P          65          0
# 4   DUE2948    NY  03/14/2020         08:47A          65          0
# 5   HBR7395    NY  03/17/2020         11:08A          65          0
# 6   HPH8866    NY  03/17/2020         11:06A          65          0
# 7   JJY1970    NY  03/17/2020         12:54P          65          0
# 8   HWG9982    NY  03/17/2020         12:45P          65          0
# 9   JCL6911    NY  03/13/2020         08:15A          65          0
#
#   Payment_Amount Precinct County         time_issued
# 0             65      046     BX 2020-03-17 08:48:00
# 1             65      077      K 2020-03-12 09:37:00
# 2             65      060      K 2020-03-17 10:00:00
# 3             65      067      K 2020-03-17 12:28:00
# 4             65      068      K 2020-03-14 08:47:00
# 5             65      026     NY 2020-03-17 11:08:00
# 6             65      026     NY 2020-03-17 11:06:00
# 7             65      062      K 2020-03-17 12:54:00
# 8             65      062      K 2020-03-17 12:45:00
# 9             65      070      K 2020-03-13 08:15:00

# %%
violation_df.drop(['Violation_Time', 'Issue_Date'], axis=1, inplace=True)
violation_df.loc[violation_df['time_issued']=='NaT', 'time_issued']= np.nan 
violation_df.dropna(inplace = True)

# %%
violation_df['Precinct'] = violation_df['Precinct'].astype(float)
violation_df['Fine_Amount'] = violation_df['Fine_Amount'].astype(float)
violation_df['Amount_Due'] = violation_df['Amount_Due'].astype(float)
violation_df['Payment_Amount'] = violation_df['Amount_Due'].astype(float)

# %%
violation_df.loc[violation_df['Precinct']>123, 'Precinct']= np.nan 
violation_df.dropna(inplace = True)

# %%
violation_df.shape
# Out:
# (6742644, 8)

# %%
violation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6742644 entries, 0 to 6766378
# Data columns (total 8 columns):
# Plate             object
# State             object
# Fine_Amount       float64
# Amount_Due        float64
# Payment_Amount    float64
# Precinct          float64
# County            object
# time_issued       datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 463.0+ MB

# %%
violation_df.loc[violation_df['time_issued']>'2019-12-31 12:00:00', 'time_issued']= np.nan
violation_df.loc[violation_df['time_issued']<'2017-01-01 12:00:00', 'time_issued']= np.nan
violation_df.dropna(inplace = True)

# %%
min(violation_df['time_issued'])
# Out:
# Timestamp('2017-01-02 00:00:00')

# %%
max(violation_df['time_issued'])
# Out:
# Timestamp('2019-12-31 12:00:00')

# %%
violation_df.shape
# Out:
# (5002944, 8)

# %%
# move cols

violation_df = violation_df[[ 'Plate','time_issued', 'Fine_Amount', 'Amount_Due', 'Payment_Amount',
       'Precinct', 'County', 'State']]
violation_df.head()
# Out:
#        Plate         time_issued  Fine_Amount  Amount_Due  Payment_Amount  \
# 258  JPF1565 2019-12-31 11:16:00         45.0         0.0             0.0
# 322  HZG4714 2019-12-31 08:10:00         45.0         0.0             0.0
# 359  HYH2149 2019-12-30 11:11:00         45.0         0.0             0.0
# 368  FGD8792 2019-12-30 09:03:00         45.0         0.0             0.0
# 369  HGM5765 2019-12-30 08:59:00         45.0         0.0             0.0
#
#      Precinct County State
# 258      61.0      K    NY
# 322      46.0     BX    NY
# 359      75.0      K    NY
# 368      88.0      K    NY
# 369      88.0      K    NY

# %%
violation_df['weekday'] = violation_df['time_issued'].dt.weekday
county_dummies = pd.get_dummies(violation_df['County'], prefix='County')
weekday_dummies = pd.get_dummies(violation_df['weekday'], prefix='weekday')
violation_df = pd.concat([violation_df, county_dummies, weekday_dummies], axis=1)
violation_df.drop(columns =['County','weekday'], inplace=True)
violation_df.columns
# Out:
# Index(['Plate', 'time_issued', 'Fine_Amount', 'Amount_Due', 'Payment_Amount',
#        'Precinct', 'State', 'County_BX', 'County_K', 'County_NY', 'County_Q',
#        'County_R', 'weekday_0', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5', 'weekday_6'],
#       dtype='object')

# %%
violation_df.rename(columns={'County_BX':'Bronx', 'County_K':'Brooklyn', \
                             'County_NY':'Manhattan', 'County_Q':'Queens', \
                             'County_R':'Staten_Island'}, inplace=True)

# violation_df.loc[violation_df['Staten_Island']==1, 'Staten_Island'] = np.nan 
# violation_df.dropna(inplace = True)
# violation_df.shape

# %%
#Clean this up later

violation_df.loc[violation_df['State'] =='NY', 'State']= 1

out_of_state = {'FL':0, 'NJ':0, 'MI':0, 'RI':0, 'PA':0, 'VA':0, 'ME':0, 'CT':0, 'NC':0, 'AL':0,
       'TX':0, 'IL':0, 'MA':0, 'WI':0, 'IN':0, 'GV':0, 'NH':0, 'OH':0, '99':0, 'AZ':0, 'CA':0,
       'SC':0, 'LA':0, 'GA':0, 'VT':0, 'OR':0, 'MD':0, 'SD':0, 'MO':0, 'DE':0, 'WV':0, 'OK':0,
       'ON':0, 'CO':0, 'AR':0, 'AK':0, 'QB':0, 'WA':0, 'MT':0, 'NV':0, 'UT':0, 'TN':0, 'DC':0, 'YT':0,
       'NE':0, 'KY':0, 'IA':0, 'MN':0, 'ID':0, 'KS':0, 'ND':0, 'MS':0, 'NM':0, 'WY':0, 'HI':0, 'NF':0,
       'MX':0, 'DP':0, 'AB':0, 'NS':0, 'BC':0, 'PR':0, 'NB':0, 'FO':0, 'MB':0, 'PE':0, 'SK':0, 'NT':0}

violation_df['State'].replace(out_of_state, inplace = True)
violation_df['State'].value_counts()
# Out:
# 1    3807953
# 0    1194991
# Name: State, dtype: int64

# %%
violation_df.rename(columns={'Precinct':'precinct'}, inplace=True)
violation_df.head()
# Out:
#        Plate         time_issued  Fine_Amount  Amount_Due  Payment_Amount  \
# 258  JPF1565 2019-12-31 11:16:00         45.0         0.0             0.0
# 322  HZG4714 2019-12-31 08:10:00         45.0         0.0             0.0
# 359  HYH2149 2019-12-30 11:11:00         45.0         0.0             0.0
# 368  FGD8792 2019-12-30 09:03:00         45.0         0.0             0.0
# 369  HGM5765 2019-12-30 08:59:00         45.0         0.0             0.0
#
#      precinct  State  Bronx  Brooklyn  Manhattan  Queens  Staten_Island  \
# 258      61.0      1      0         1          0       0              0
# 322      46.0      1      1         0          0       0              0
# 359      75.0      1      0         1          0       0              0
# 368      88.0      1      0         1          0       0              0
# 369      88.0      1      0         1          0       0              0
#
#      weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# 258          0          1          0          0          0          0
# 322          0          1          0          0          0          0
# 359          1          0          0          0          0          0
# 368          1          0          0          0          0          0
# 369          1          0          0          0          0          0
#
#      weekday_6
# 258          0
# 322          0
# 359          0
# 368          0
# 369          0

# %%
zero_dict = {0: np.nan}
violation_df['precinct'].replace(zero_dict, inplace = True)
violation_df.dropna(inplace = True)

violation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000970 entries, 258 to 6766368
# Data columns (total 19 columns):
# Plate             object
# time_issued       datetime64[ns]
# Fine_Amount       float64
# Amount_Due        float64
# Payment_Amount    float64
# precinct          float64
# State             int64
# Bronx             uint8
# Brooklyn          uint8
# Manhattan         uint8
# Queens            uint8
# Staten_Island     uint8
# weekday_0         uint8
# weekday_1         uint8
# weekday_2         uint8
# weekday_3         uint8
# weekday_4         uint8
# weekday_5         uint8
# weekday_6         uint8
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1), uint8(12)
# memory usage: 362.5+ MB

# %%
sns.heatmap(violation_df.isnull(), cbar=False)

# %%
violation_df.head()
# Out:
#        Plate         time_issued  Fine_Amount  Amount_Due  Payment_Amount  \
# 258  JPF1565 2019-12-31 11:16:00         45.0         0.0             0.0
# 322  HZG4714 2019-12-31 08:10:00         45.0         0.0             0.0
# 359  HYH2149 2019-12-30 11:11:00         45.0         0.0             0.0
# 368  FGD8792 2019-12-30 09:03:00         45.0         0.0             0.0
# 369  HGM5765 2019-12-30 08:59:00         45.0         0.0             0.0
#
#      precinct  State  Bronx  Brooklyn  Manhattan  Queens  Staten_Island  \
# 258      61.0      1      0         1          0       0              0
# 322      46.0      1      1         0          0       0              0
# 359      75.0      1      0         1          0       0              0
# 368      88.0      1      0         1          0       0              0
# 369      88.0      1      0         1          0       0              0
#
#      weekday_0  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# 258          0          1          0          0          0          0
# 322          0          1          0          0          0          0
# 359          1          0          0          0          0          0
# 368          1          0          0          0          0          0
# 369          1          0          0          0          0          0
#
#      weekday_6
# 258          0
# 322          0
# 359          0
# 368          0
# 369          0

# %%
violation_df.to_csv('ParkingTickets_200414.csv')
